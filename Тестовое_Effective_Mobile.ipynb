# %% [markdown]
# БЛОК 1:  Теория вероятности и логика

# %% [markdown]
# Система безопасности ювелирного бутика получает шумовой сигнал с вероятность 0.4, а сигнал тревоги – с вероятностью 0.6. При получении системой шума, она срабатывает с вероятностью 0.2. Если поступает чистый сигнал тревоги – срабатывает с вероятностью 0,8. Известно, что система сработала. Найти вероятность того, что в сигнале был реальный сигнал тревоги.
#
# Ответ округлить до тысячных.
#
# Формат ответа: значение вероятности в долях, например: 0.721

# %% [markdown]
# Формула полной вероятности Байеса
# 2 гипотезы
# н1 -Получен реальный сигнал тревоги p(н1)=0,8
# н2 -Получен шумовой сигнал тревоги p(h2)=0,2
#
#
# A система безопастности зафиксировала реальный сигнал
# A(h1)=0.6-и сработал сигнал тревоги
# A(h2)=0.4 -получила шумовй сигнал
#
# P(h1)*p(A/H1)/
# P(H1)*P(A/H1)+P(H2)*P(A/H2)
#
# 0.8*0,6
# 0.8*0,6+0,2*0,4=0,48/0,48+0,08=0,48/0,56 =0,8571

# %% [markdown]
# Кулинарное соревнование.
#
# В конкурсе участвуют 80 шеф-поваров с уникальными уровнями мастерства. В первом этапе судьи случайным образом распределяют их по парам (в любом состязании двух шефов выигрывает тот, у кого выше уровень мастерства). На втором этапе шефы снова случайно образуют пары для финального раунда (пары могут повториться). Победную награду получают те, кто выиграл в обоих этапах.
#
# Каково математическое ожидание числа победителей?
#
# Ответ округлите до десятых, например: 33,5

# %% [markdown]
# *Так как в первом этапе у нас 40 победителей, и вероятность победы каждого из них на втором этапе 0.5. 40*0.5 = 20*

# %% [markdown]
# Два скоростных состава, на расстоянии в 350 км друг от друга, движутся навстречу по параллельным железнодорожным колеям. Скорость первого 95 км/ч, а второго – 105 км/ч. Ястреб, летящий со скоростью 160 км/ч, вылетает от поезда А в момент начала движения составов, затем долетает до поезда Б, разворачивается и летит обратно к приближающемуся поезду А – и так снова и снова, пока поезда не встретятся.
#
# Какое расстояние пролетит ястреб до момента встречи поездов?
#
# Формат ответа: целое число в км, например: 60

# %% [markdown]
# *Найдем время когда поезда встретяться 350/105+95 =1,75 часа
# За 1.7 часа ястреб пролетит 160 * 1.75 = 280*

# %% [markdown]
# БЛОК 2:  Python и визуализация

# %% [markdown]
# Как можно изменить все значения в столбце DataFrame на их квадраты?
#
# Выберите только верные варианты:
#
# * df['column'] = df['column'] ** 2
# * df['column'] = df['column'].apply(lambda x: x ** 2)
# * df['column'] = df['column'].map(lambda x: x ** 2)
# * Все выше перечисленные способы.

# %% [markdown]
# Все *вышеперчисленные*

# %% [markdown]
# Дан список словарей, где каждый словарь содержит информацию о возрасте человека. Необходимо найти средний возраст людей в списке.
#
# people = [ {"name": "Алексей", "age": 30}, {"name": "Мария", "age": 25},
# {"name": "Иван", "age": 35} ]
#
# Выберите верные варианты реализации кода:
#
# * average_age = sum(person["age"] for person in people) / len(people)
# * average_age = sum(people["age"]) / len(people)
# * average_age = sum([person["age"] for person in people]) / len([person["age"] for person in people])
# * average_age = sum(map(lambda x: x.get("age"), people)) / people.count()

# %% [markdown]
# *average_age = sum(person["age"] for person in people) / len(people)
# average_age  = sum([person["age"] for person in people]) / len([person["age"] for person in people*

# %% [markdown]
# Алиса, Пётр и Мария договорились объединить свои подарочные конфеты на Новый год и разделить их поровну между собой. Ради дружбы все лишние конфеты будут выброшены. Например, если они вместе принесут домой 91 конфету, то возьмут по 30 и оставят 1.
#
# Напишите арифметическое выражение ниже, которое определит: сколько конфет они должны выбросить. Известные переменные: alice_candies, petr_candies, mary_candies
#
# Формат ответа: Python-код в строку, без пробелов, например: (alice_candies+petr_candies+mary_candies)//3

# %% [markdown]
# *(alice_candies + petr_candies + mary_candies) % 3*

# %% [markdown]
# БЛОК 3:  SQL

# %% [markdown]
# Какой из операторов: SELECT, FROM, JOIN, WHERE, GROUP BY, HAVING - будет выполняться последним при обработке запроса?
# *
# 2 балла
# SELECT
# FROM
# JOIN
# WHERE
# GROUP BY
# HAVING

# %% [markdown]
# *Having*

# %% [markdown]
# Сколько будет 5 + NULL?
# *
# 1 балл
# 5
# Запрос упадёт в ошибку
# NULL
# FALSE

# %% [markdown]
# *Null*

# %% [markdown]
# Представьте две таблицы: первая содержит 30 строк, а вторая — 20 строк. Мы выполняем операцию FULL JOIN между ними.
#
# Какой диапазон возможного количества строк может быть в результирующей таблице, если учесть, что ключи для соединения могут быть как полностью совпадающими, так и абсолютно уникальными?
#
# Ответ в краткой форме, например: минимально 10 и максимально 3000 строк

# %% [markdown]
# *Минимальное количество это максимум из 2 таблиц 30 и 20 т.е 30 а максимально если не нашлись совпадения 30+20=50*
#
# ---

# %% [markdown]
# БЛОК 4:  Статистика и АБ-тесты

# %% [markdown]
# Вы – аналитик компании Самокат (сервис по доставке продуктов на дом).
#
# Команда решила протестировать гениальную идею замены транспортного средства доставщиков и провели АБ эксперимент в небольшом городке РФ. Результаты превзошли все ожидания: время доставки значимо снизилось в несколько раз! Руководству не терпится применить изменения по всей стране.
#
# Делаем? Выберите все верные утверждения:
# *
# 3 балла
# * Делаем. Только применяем изменения в таком же масштабе (количество транспортных средств с изменением), как в городе, где проводили тест.
# * Тест нерепрезентативен, поэтому результаты применять по всей стране нельзя.
# * Тест репрезентативен относительно своей генеральной совокупности: таких же небольших городов, можем применять только в подобных городах.
# * Наличие эффекта подтвердило потенциал идеи, поэтому сразу применять по всем городам не будет, но можем провести эксперимент в других городах.

# %% [markdown]
# * Тест репрезентативен относительно своей генеральной совокупности: таких же небольших городов, можем применять только в подобных городах.
# * Наличие эффекта подтвердило потенциал идеи, поэтому сразу применять по всем городам не будет, но можем провести эксперимент в других городах.

# %% [markdown]
# Что такое p-value в статистическом тестировании
# * Вероятность, что нулевая гипотеза верна
# * Вероятность наблюдения такого или более экстремального результата при условии, что нулевая гипотеза верна
# * Значение уровня значимости, при котором отвергается нулевая гипотеза
# Среднее значение выборки

# %% [markdown]
# *Вероятность наблюдения такого или более экстремального результата при условии, что нулевая гипотеза верна*

# %% [markdown]
# Какое значение коэффициента корреляции указывает на отсутствие линейной зависимости между переменными?
# *
# 1 балл
# 0
# 1
# -1
# 0.5

# %% [markdown]
# *0*

# %% [markdown]
# БЛОК 5: ML Base

# %% [markdown]
# Вас просят разработать модель, классифицирующую лошадок и пони. Вместо разработки вы нашли на GitHub две интересные модели и после прогона на ваших данных одна из них показала ROC-AUC=0.7, а другая ROC-AUC=0.1.
#
# Какую модель вы возьмете для дальнейшей работы и что будете с ней делать?
#
# Формат ответа: развернутый, но кратко, например: "первую, отниму от метрики 0.1 для корректировки точности"

# %% [markdown]
# *Выберу первую,проведу анализ производительности,настройки гиперпараметров,новые признаки*

# %% [markdown]
# В машинном обучении задача предсказания выживаемости на Титанике стала классической.
#
# Перечислите топ-3 признака (фичи), которые в лучшей степени характеризовали целевой признак (1 - пассажир выжил, 0 - нет).
#
# Подумайте, какой признак был наиболее важным с точки зрения выживаемости?

# %% [markdown]
# *Топ3-пол,возраст,каюта. Самый важный пол*

# %% [markdown]
# ML-модель классифицирует 100 картинок, среди которых 80 - котиков и 20 - собачек. Из 80 котиков алгоритм определил верно 75 примеров, а среди фото с собачками - всего 9 фото.
#
# Рассчитайте метрику точности (Accuracy) алгоритма.
#
# Формат ответа: в долях, без округления, например: 0.63

# %% [markdown]
# *Accuracy=Количество верно классифицированных примеров /Общее количество примеров
# Количество верно классифицированных примеров=75+9=84
# Общее ко-во 100
# 84/100=0.84*

# %% [markdown]
# Вроде как неверные ответы у вопросов
# * Система безопасности ювелирного бутика получает шумовой сигнал с вероятность 0.4, а сигнал тревоги – с вероятностью 0.6. При получении системой шума, она срабатывает с вероятностью 0.2. Если поступает чистый сигнал тревоги – срабатывает с вероятностью 0,8. Известно, что система сработала. Найти вероятность того, что в сигнале был реальный сигнал тревоги.
# * В конкурсе участвуют 80 шеф-поваров с уникальными уровнями мастерства. В первом этапе судьи случайным образом распределяют их по парам (в любом состязании двух шефов выигрывает тот, у кого выше уровень мастерства). На втором этапе шефы снова случайно образуют пары для финального раунда (пары могут повториться). Победную награду получают те, кто выиграл в обоих этапах.
# * Как можно изменить все значения в столбце DataFrame на их квадраты?
# * Дан список словарей, где каждый словарь содержит информацию о возрасте человека. Необходимо найти средний возраст людей в списке. people = [ {"name": "Алексей", "age": 30}, {"name": "Мария", "age": 25},
# {"name": "Иван", "age": 35} ]
# * Алиса, Пётр и Мария договорились объединить свои подарочные конфеты на Новый год и разделить их поровну между собой. Ради дружбы все лишние конфеты будут выброшены. Например, если они вместе принесут домой 91 конфету, то возьмут по 30 и оставят 1.
#
# * Какой из операторов: SELECT, FROM, JOIN, WHERE, GROUP BY, HAVING - будет выполняться последним при обработке запроса?
# * Представьте две таблицы: первая содержит 30 строк, а вторая — 20 строк. Мы выполняем операцию FULL JOIN между ними
#
# * Вы – аналитик компании Самокат (сервис по доставке продуктов на дом).Команда решила протестировать гениальную идею замены транспортного средства доставщиков и провели АБ эксперимент в небольшом городке РФ. Результаты превзошли все ожидания: время доставки значимо снизилось в несколько раз! Руководству не терпится применить изменения по всей стране.
